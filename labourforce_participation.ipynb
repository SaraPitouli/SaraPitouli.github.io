# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraPitouli/SaraPitouli.github.io/blob/main/labourforce_participation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import json

# %%
from google.colab import files

# %%
url="https://api.worldbank.org/v2/country/all/indicator/SL.TLF.CACT.FE.ZS;SL.TLF.CACT.FE.NE.ZS;SL.TLF.CACT.MA.ZS;SL.TLF.CACT.MA.NE.ZS;SL.TLF.CACT.ZS;SL.TLF.CACT.NE.ZS;SL.TLF.ACTI.1524.FE.ZS;SL.TLF.ACTI.1524.FE.NE.ZS;SL.TLF.ACTI.1524.MA.ZS;SL.TLF.ACTI.1524.MA.NE.ZS;SL.TLF.ACTI.1524.ZS;SL.TLF.ACTI.1524.NE.ZS;SL.TLF.ACTI.FE.ZS;SL.TLF.ACTI.MA.ZS;SL.TLF.ACTI.ZS?source=14&page=1&format=json&date=2019:2021&per_page=12000"

# %%
data = requests.get(url).json()

# %%
data
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 12000,
#   'total': 11925,
#   'sourceid': None,
#   'sourcename': None,
#   'lastupdated': '2022-06-23'},
#  [{'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 64.8781205227162,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 64.1118907910899,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 66.3621421726286,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2021',
#    'value': 52.9908717386045,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2020',
#    'value': 52.7646289415164,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2019',
#    'value': 53.977916120396,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2021',
#    'value': 19.6859746486133,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2020',
#    'value': 19.6319728888944,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2019',
#    'value': 20.074262497125,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2021',
#    'value': 51.7607775965804,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2020',
#    'value': 50.8563111937574,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'countryiso3code': 'CSS',
#    'date': '2019',
#    'value': 54.1587068242199,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2021',
#    'value': 49.2294579318018,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2020',
#    'value': 48.716122580343,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'countryiso3code': 'CEB',
#    'date': '2019',
#    'value': 49.0592329319353,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2021',
#    'value': 31.9815742379871,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2020',
#    'value': 31.1050910407028,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'countryiso3code': 'EAR',
#    'date': '2019',
#    'value': 33.5229313264294,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2021',
#    'value': 59.0438953356278,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2020',
#    'value': 59.1201808629792,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'countryiso3code': 'EAS',
#    'date': '2019',
#    'value': 60.2515766231354,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2021',
#    'value': 59.6637673935087,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2020',
#    'value': 59.7758208794032,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'countryiso3code': 'EAP',
#    'date': '2019',
#    'value': 61.0111171659761,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#    'countryiso3code': 'TEA',
#    'date': '2021',
#    'value': 59.4378206830325,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#    'countryiso3code': 'TEA',
#    'date': '2020',
#    'value': 59.546762541739,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#    'countryiso3code': 'TEA',
#    'date': '2019',
#    'value': 60.7862101031074,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2021',
#    'value': 51.7102356368954,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2020',
#    'value': 51.0805394941271,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'countryiso3code': 'EMU',
#    'date': '2019',
#    'value': 51.6494678104009,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2021',
#    'value': 50.320393015144,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2020',
#    'value': 50.1371824421912,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'countryiso3code': 'ECS',
#    'date': '2019',
#    'value': 50.9798474010091,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2021',
#    'value': 47.1947100609539,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2020',
#    'value': 47.4400788364109,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'countryiso3code': 'ECA',
#    'date': '2019',
#    'value': 48.790003424847,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#    'countryiso3code': 'TEC',
#    'date': '2021',
#    'value': 47.3556817889513,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#    'countryiso3code': 'TEC',
#    'date': '2020',
#    'value': 47.4513801083155,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#    'countryiso3code': 'TEC',
#    'date': '2019',
#    'value': 48.6987277300112,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2021',
#    'value': 51.3220573428215,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2020',
#    'value': 50.7248944098124,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'EU', 'value': 'European Union'},
#    'countryiso3code': 'EUU',
#    'date': '2019',
#    'value': 51.248444375789,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2021',
#    'value': 48.2664470925801,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2020',
#    'value': 48.1046575357814,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'F1',
#     'value': 'Fragile and conflict affected situations'},
#    'countryiso3code': 'FCS',
#    'date': '2019',
#    'value': 49.9370257485978,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2021',
#    'value': 60.4715153515955,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2020',
#    'value': 59.8657232210582,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2019',
#    'value': 61.9015942349929,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2021',
#    'value': 53.3241310943921,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2020',
#    'value': 53.0777532224904,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2019',
#    'value': 53.7554733926414,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2021',
#    'value': 43.4395475682325,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2020',
#    'value': 43.0030231544376,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XF', 'value': 'IBRD only'},
#    'countryiso3code': 'IBD',
#    'date': '2019',
#    'value': 45.1992500682206,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2021',
#    'value': 44.7142495617886,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2020',
#    'value': 44.2893295563627,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#    'countryiso3code': 'IBT',
#    'date': '2019',
#    'value': 46.3671227117556,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2021',
#    'value': 41.0412544592657,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2020',
#    'value': 40.7938225114218,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XH', 'value': 'IDA blend'},
#    'countryiso3code': 'IDB',
#    'date': '2019',
#    'value': 41.9289211039719,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2021',
#    'value': 53.1043451986423,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2020',
#    'value': 52.7667614400708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XI', 'value': 'IDA only'},
#    'countryiso3code': 'IDX',
#    'date': '2019',
#    'value': 54.7984905205647,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2021',
#    'value': 49.1198901151546,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2020',
#    'value': 48.8070863185312,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XG', 'value': 'IDA total'},
#    'countryiso3code': 'IDA',
#    'date': '2019',
#    'value': 50.5382194375915,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2021',
#    'value': 57.8649015056048,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2020',
#    'value': 57.8585577524786,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#    'countryiso3code': 'LTE',
#    'date': '2019',
#    'value': 59.4882482329463,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2021',
#    'value': 48.5053462292949,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2020',
#    'value': 46.0923869318955,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#    'countryiso3code': 'LCN',
#    'date': '2019',
#    'value': 51.0705999751138,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2021',
#    'value': 49.3584302903,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2020',
#    'value': 46.7107325998303,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'countryiso3code': 'LAC',
#    'date': '2019',
#    'value': 51.8911998009929,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#    'countryiso3code': 'TLA',
#    'date': '2021',
#    'value': 48.7459222863201,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#    'countryiso3code': 'TLA',
#    'date': '2020',
#    'value': 46.2939677219892,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#    'countryiso3code': 'TLA',
#    'date': '2019',
#    'value': 51.3393541597499,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2021',
#    'value': 54.696573259058,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2020',
#    'value': 54.324637059507,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XL',
#     'value': 'Least developed countries: UN classification'},
#    'countryiso3code': 'LDC',
#    'date': '2019',
#    'value': 56.432373628826,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XO', 'value': 'Low & middle income'},
#    'countryiso3code': 'LMY',
#    'date': '2021',
#    'value': 44.8428114771401,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XO', 'value': 'Low & middle income'},
#    'countryiso3code': 'LMY',
#    'date': '2020',
#    'value': 44.4236429975584,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XO', 'value': 'Low & middle income'},
#    'countryiso3code': 'LMY',
#    'date': '2019',
#    'value': 46.5046194399056,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XM', 'value': 'Low income'},
#    'countryiso3code': '',
#    'date': '2021',
#    'value': 56.804493186196,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XM', 'value': 'Low income'},
#    'countryiso3code': '',
#    'date': '2020',
#    'value': 56.4437552492749,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XM', 'value': 'Low income'},
#    'countryiso3code': '',
#    'date': '2019',
#    'value': 58.6129258047632,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XN', 'value': 'Lower middle income'},
#    'countryiso3code': '',
#    'date': '2021',
#    'value': 33.5871886698911,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XN', 'value': 'Lower middle income'},
#    'countryiso3code': '',
#    'date': '2020',
#    'value': 33.0729978765373,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XN', 'value': 'Lower middle income'},
#    'countryiso3code': '',
#    'date': '2019',
#    'value': 35.0228965465182,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#    'countryiso3code': 'MEA',
#    'date': '2021',
#    'value': 18.6061975464682,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#    'countryiso3code': 'MEA',
#    'date': '2020',
#    'value': 18.4899322414378,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#    'countryiso3code': 'MEA',
#    'date': '2019',
#    'value': 19.4184516540925,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XQ',
#     'value': 'Middle East & North Africa (excluding high income)'},
#    'countryiso3code': 'MNA',
#    'date': '2021',
#    'value': 15.5750315587062,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XQ',
#     'value': 'Middle East & North Africa (excluding high income)'},
#    'countryiso3code': 'MNA',
#    'date': '2020',
#    'value': 15.40314732385,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XQ',
#     'value': 'Middle East & North Africa (excluding high income)'},
#    'countryiso3code': 'MNA',
#    'date': '2019',
#    'value': 16.7020940872534,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#    'countryiso3code': 'TMN',
#    'date': '2021',
#    'value': 15.5630376569383,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#    'countryiso3code': 'TMN',
#    'date': '2020',
#    'value': 15.3949561021216,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#    'countryiso3code': 'TMN',
#    'date': '2019',
#    'value': 16.6873445920004,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XP', 'value': 'Middle income'},
#    'countryiso3code': 'MIC',
#    'date': '2021',
#    'value': 43.7395051113457,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XP', 'value': 'Middle income'},
#    'countryiso3code': 'MIC',
#    'date': '2020',
#    'value': 43.3355168533402,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XP', 'value': 'Middle income'},
#    'countryiso3code': 'MIC',
#    'date': '2019',
#    'value': 45.4291426160624,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XU', 'value': 'North America'},
#    'countryiso3code': 'NAC',
#    'date': '2021',
#    'value': 55.815312067561,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XU', 'value': 'North America'},
#    'countryiso3code': 'NAC',
#    'date': '2020',
#    'value': 55.8249254962835,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'XU', 'value': 'North America'},
#    'countryiso3code': 'NAC',
#    'date': '2019',
#    'value': 57.1069801005648,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'OE', 'value': 'OECD members'},
#    'countryiso3code': 'OED',
#    'date': '2021',
#    'value': 51.7968341361096,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'OE', 'value': 'OECD members'},
#    'countryiso3code': 'OED',
#    'date': '2020',
#    'value': 51.2047283394638,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'OE', 'value': 'OECD members'},
#    'countryiso3code': 'OED',
#    'date': '2019',
#    'value': 52.5793238362361,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'countryiso3code': 'OSS',
#    'date': '2021',
#    'value': 50.4454919795437,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'countryiso3code': 'OSS',
#    'date': '2020',
#    'value': 50.2656611867821,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'countryiso3code': 'OSS',
#    'date': '2019',
#    'value': 51.605690373572,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'countryiso3code': 'PSS',
#    'date': '2021',
#    'value': 53.2623404996813,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'countryiso3code': 'PSS',
#    'date': '2020',
#    'value': 53.1868677291755,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'countryiso3code': 'PSS',
#    'date': '2019',
#    'value': 53.6367828105726,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'countryiso3code': 'PST',
#    'date': '2021',
#    'value': 53.8655683477543,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'countryiso3code': 'PST',
#    'date': '2020',
#    'value': 53.6432714169708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'countryiso3code': 'PST',
#    'date': '2019',
#    'value': 54.3905008082019,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'countryiso3code': 'PRE',
#    'date': '2021',
#    'value': 55.1451531143271,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'countryiso3code': 'PRE',
#    'date': '2020',
#    'value': 54.8863834785987,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'countryiso3code': 'PRE',
#    'date': '2019',
#    'value': 56.4204401996629,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S1', 'value': 'Small states'},
#    'countryiso3code': 'SST',
#    'date': '2021',
#    'value': 50.8560063004472,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S1', 'value': 'Small states'},
#    'countryiso3code': 'SST',
#    'date': '2020',
#    'value': 50.5366837000198,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'S1', 'value': 'Small states'},
#    'countryiso3code': 'SST',
#    'date': '2019',
#    'value': 52.2319067506659,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '8S', 'value': 'South Asia'},
#    'countryiso3code': 'SAS',
#    'date': '2021',
#    'value': 21.9904971349328,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '8S', 'value': 'South Asia'},
#    'countryiso3code': 'SAS',
#    'date': '2020',
#    'value': 21.4377477522558,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': '8S', 'value': 'South Asia'},
#    'countryiso3code': 'SAS',
#    'date': '2019',
#    'value': 23.8605625388155,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#    'countryiso3code': 'TSA',
#    'date': '2021',
#    'value': 21.9904971349328,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#    'countryiso3code': 'TSA',
#    'date': '2020',
#    'value': 21.4377477522558,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#    'countryiso3code': 'TSA',
#    'date': '2019',
#    'value': 23.8605625388155,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#    'countryiso3code': 'SSF',
#    'date': '2021',
#    'value': 60.2199085708754,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#    'countryiso3code': 'SSF',
#    'date': '2020',
#    'value': 59.663110138779,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#    'countryiso3code': 'SSF',
#    'date': '2019',
#    'value': 61.5047379689282,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'countryiso3code': 'SSA',
#    'date': '2021',
#    'value': 60.2199085708754,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'countryiso3code': 'SSA',
#    'date': '2020',
#    'value': 59.663110138779,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#    'country': {'id': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'countryiso3code': 'SSA',
#    'date': '2019',
#    'value': 61.5047379689282,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
# ...
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AD', 'value': 'Andorra'},
#    'countryiso3code': 'AND',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AO', 'value': 'Angola'},
#    'countryiso3code': 'AGO',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AO', 'value': 'Angola'},
#    'countryiso3code': 'AGO',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AO', 'value': 'Angola'},
#    'countryiso3code': 'AGO',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#    'countryiso3code': 'ATG',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#    'countryiso3code': 'ATG',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#    'countryiso3code': 'ATG',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2020',
#    'value': 46.810001373291,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AR', 'value': 'Argentina'},
#    'countryiso3code': 'ARG',
#    'date': '2019',
#    'value': 50.2999992370605,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AM', 'value': 'Armenia'},
#    'countryiso3code': 'ARM',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AM', 'value': 'Armenia'},
#    'countryiso3code': 'ARM',
#    'date': '2020',
#    'value': 46.2799987792969,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AM', 'value': 'Armenia'},
#    'countryiso3code': 'ARM',
#    'date': '2019',
#    'value': 49.4300003051758,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AW', 'value': 'Aruba'},
#    'countryiso3code': 'ABW',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AW', 'value': 'Aruba'},
#    'countryiso3code': 'ABW',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AW', 'value': 'Aruba'},
#    'countryiso3code': 'ABW',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2021',
#    'value': 61.2200012207031,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2020',
#    'value': 60.2099990844727,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2019',
#    'value': 60.9599990844727,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AT', 'value': 'Austria'},
#    'countryiso3code': 'AUT',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AT', 'value': 'Austria'},
#    'countryiso3code': 'AUT',
#    'date': '2020',
#    'value': 55.6399993896484,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AT', 'value': 'Austria'},
#    'countryiso3code': 'AUT',
#    'date': '2019',
#    'value': 56,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#    'countryiso3code': 'AZE',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#    'countryiso3code': 'AZE',
#    'date': '2020',
#    'value': 64,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#    'countryiso3code': 'AZE',
#    'date': '2019',
#    'value': 63.2999992370605,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BS', 'value': 'Bahamas, The'},
#    'countryiso3code': 'BHS',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BS', 'value': 'Bahamas, The'},
#    'countryiso3code': 'BHS',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BS', 'value': 'Bahamas, The'},
#    'countryiso3code': 'BHS',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BH', 'value': 'Bahrain'},
#    'countryiso3code': 'BHR',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BH', 'value': 'Bahrain'},
#    'countryiso3code': 'BHR',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BH', 'value': 'Bahrain'},
#    'countryiso3code': 'BHR',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BD', 'value': 'Bangladesh'},
#    'countryiso3code': 'BGD',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BD', 'value': 'Bangladesh'},
#    'countryiso3code': 'BGD',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BD', 'value': 'Bangladesh'},
#    'countryiso3code': 'BGD',
#    'date': '2019',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BB', 'value': 'Barbados'},
#    'countryiso3code': 'BRB',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BB', 'value': 'Barbados'},
#    'countryiso3code': 'BRB',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BB', 'value': 'Barbados'},
#    'countryiso3code': 'BRB',
#    'date': '2019',
#    'value': 59.0299987792969,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BY', 'value': 'Belarus'},
#    'countryiso3code': 'BLR',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BY', 'value': 'Belarus'},
#    'countryiso3code': 'BLR',
#    'date': '2020',
#    'value': 65.6800003051758,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BY', 'value': 'Belarus'},
#    'countryiso3code': 'BLR',
#    'date': '2019',
#    'value': 66.3000030517578,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BE', 'value': 'Belgium'},
#    'countryiso3code': 'BEL',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BE', 'value': 'Belgium'},
#    'countryiso3code': 'BEL',
#    'date': '2020',
#    'value': 49.3400001525879,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BE', 'value': 'Belgium'},
#    'countryiso3code': 'BEL',
#    'date': '2019',
#    'value': 49.8300018310547,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BZ', 'value': 'Belize'},
#    'countryiso3code': 'BLZ',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BZ', 'value': 'Belize'},
#    'countryiso3code': 'BLZ',
#    'date': '2020',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BZ', 'value': 'Belize'},
#    'countryiso3code': 'BLZ',
#    'date': '2019',
#    'value': 57.189998626709,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#     'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#    'country': {'id': 'BJ', 'value': 'Benin'},
#    'countryiso3code': 'BEN',
#    'date': '2021',
#    'value': None,
#    'scale': '',
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   ...]]

# %%
data[1]
# Out:
# [{'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 64.8781205227162,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2020',
#   'value': 64.1118907910899,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2019',
#   'value': 66.3621421726286,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '2021',
#   'value': 52.9908717386045,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '2020',
#   'value': 52.7646289415164,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '2019',
#   'value': 53.977916120396,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '1A', 'value': 'Arab World'},
#   'countryiso3code': 'ARB',
#   'date': '2021',
#   'value': 19.6859746486133,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '1A', 'value': 'Arab World'},
#   'countryiso3code': 'ARB',
#   'date': '2020',
#   'value': 19.6319728888944,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '1A', 'value': 'Arab World'},
#   'countryiso3code': 'ARB',
#   'date': '2019',
#   'value': 20.074262497125,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S3', 'value': 'Caribbean small states'},
#   'countryiso3code': 'CSS',
#   'date': '2021',
#   'value': 51.7607775965804,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S3', 'value': 'Caribbean small states'},
#   'countryiso3code': 'CSS',
#   'date': '2020',
#   'value': 50.8563111937574,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S3', 'value': 'Caribbean small states'},
#   'countryiso3code': 'CSS',
#   'date': '2019',
#   'value': 54.1587068242199,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#   'countryiso3code': 'CEB',
#   'date': '2021',
#   'value': 49.2294579318018,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#   'countryiso3code': 'CEB',
#   'date': '2020',
#   'value': 48.716122580343,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#   'countryiso3code': 'CEB',
#   'date': '2019',
#   'value': 49.0592329319353,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#   'countryiso3code': 'EAR',
#   'date': '2021',
#   'value': 31.9815742379871,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#   'countryiso3code': 'EAR',
#   'date': '2020',
#   'value': 31.1050910407028,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#   'countryiso3code': 'EAR',
#   'date': '2019',
#   'value': 33.5229313264294,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#   'countryiso3code': 'EAS',
#   'date': '2021',
#   'value': 59.0438953356278,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#   'countryiso3code': 'EAS',
#   'date': '2020',
#   'value': 59.1201808629792,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#   'countryiso3code': 'EAS',
#   'date': '2019',
#   'value': 60.2515766231354,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '4E',
#    'value': 'East Asia & Pacific (excluding high income)'},
#   'countryiso3code': 'EAP',
#   'date': '2021',
#   'value': 59.6637673935087,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '4E',
#    'value': 'East Asia & Pacific (excluding high income)'},
#   'countryiso3code': 'EAP',
#   'date': '2020',
#   'value': 59.7758208794032,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '4E',
#    'value': 'East Asia & Pacific (excluding high income)'},
#   'countryiso3code': 'EAP',
#   'date': '2019',
#   'value': 61.0111171659761,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#   'countryiso3code': 'TEA',
#   'date': '2021',
#   'value': 59.4378206830325,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#   'countryiso3code': 'TEA',
#   'date': '2020',
#   'value': 59.546762541739,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T4', 'value': 'East Asia & Pacific (IDA & IBRD)'},
#   'countryiso3code': 'TEA',
#   'date': '2019',
#   'value': 60.7862101031074,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XC', 'value': 'Euro area'},
#   'countryiso3code': 'EMU',
#   'date': '2021',
#   'value': 51.7102356368954,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XC', 'value': 'Euro area'},
#   'countryiso3code': 'EMU',
#   'date': '2020',
#   'value': 51.0805394941271,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XC', 'value': 'Euro area'},
#   'countryiso3code': 'EMU',
#   'date': '2019',
#   'value': 51.6494678104009,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#   'countryiso3code': 'ECS',
#   'date': '2021',
#   'value': 50.320393015144,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#   'countryiso3code': 'ECS',
#   'date': '2020',
#   'value': 50.1371824421912,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#   'countryiso3code': 'ECS',
#   'date': '2019',
#   'value': 50.9798474010091,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '7E',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'countryiso3code': 'ECA',
#   'date': '2021',
#   'value': 47.1947100609539,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '7E',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'countryiso3code': 'ECA',
#   'date': '2020',
#   'value': 47.4400788364109,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '7E',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'countryiso3code': 'ECA',
#   'date': '2019',
#   'value': 48.790003424847,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#   'countryiso3code': 'TEC',
#   'date': '2021',
#   'value': 47.3556817889513,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#   'countryiso3code': 'TEC',
#   'date': '2020',
#   'value': 47.4513801083155,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T7', 'value': 'Europe & Central Asia (IDA & IBRD)'},
#   'countryiso3code': 'TEC',
#   'date': '2019',
#   'value': 48.6987277300112,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'EU', 'value': 'European Union'},
#   'countryiso3code': 'EUU',
#   'date': '2021',
#   'value': 51.3220573428215,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'EU', 'value': 'European Union'},
#   'countryiso3code': 'EUU',
#   'date': '2020',
#   'value': 50.7248944098124,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'EU', 'value': 'European Union'},
#   'countryiso3code': 'EUU',
#   'date': '2019',
#   'value': 51.248444375789,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'F1', 'value': 'Fragile and conflict affected situations'},
#   'countryiso3code': 'FCS',
#   'date': '2021',
#   'value': 48.2664470925801,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'F1', 'value': 'Fragile and conflict affected situations'},
#   'countryiso3code': 'FCS',
#   'date': '2020',
#   'value': 48.1046575357814,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'F1', 'value': 'Fragile and conflict affected situations'},
#   'countryiso3code': 'FCS',
#   'date': '2019',
#   'value': 49.9370257485978,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#   'countryiso3code': 'HPC',
#   'date': '2021',
#   'value': 60.4715153515955,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#   'countryiso3code': 'HPC',
#   'date': '2020',
#   'value': 59.8657232210582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#   'countryiso3code': 'HPC',
#   'date': '2019',
#   'value': 61.9015942349929,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XD', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2021',
#   'value': 53.3241310943921,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XD', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2020',
#   'value': 53.0777532224904,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XD', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2019',
#   'value': 53.7554733926414,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XF', 'value': 'IBRD only'},
#   'countryiso3code': 'IBD',
#   'date': '2021',
#   'value': 43.4395475682325,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XF', 'value': 'IBRD only'},
#   'countryiso3code': 'IBD',
#   'date': '2020',
#   'value': 43.0030231544376,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XF', 'value': 'IBRD only'},
#   'countryiso3code': 'IBD',
#   'date': '2019',
#   'value': 45.1992500682206,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#   'countryiso3code': 'IBT',
#   'date': '2021',
#   'value': 44.7142495617886,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#   'countryiso3code': 'IBT',
#   'date': '2020',
#   'value': 44.2893295563627,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#   'countryiso3code': 'IBT',
#   'date': '2019',
#   'value': 46.3671227117556,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XH', 'value': 'IDA blend'},
#   'countryiso3code': 'IDB',
#   'date': '2021',
#   'value': 41.0412544592657,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XH', 'value': 'IDA blend'},
#   'countryiso3code': 'IDB',
#   'date': '2020',
#   'value': 40.7938225114218,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XH', 'value': 'IDA blend'},
#   'countryiso3code': 'IDB',
#   'date': '2019',
#   'value': 41.9289211039719,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XI', 'value': 'IDA only'},
#   'countryiso3code': 'IDX',
#   'date': '2021',
#   'value': 53.1043451986423,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XI', 'value': 'IDA only'},
#   'countryiso3code': 'IDX',
#   'date': '2020',
#   'value': 52.7667614400708,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XI', 'value': 'IDA only'},
#   'countryiso3code': 'IDX',
#   'date': '2019',
#   'value': 54.7984905205647,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XG', 'value': 'IDA total'},
#   'countryiso3code': 'IDA',
#   'date': '2021',
#   'value': 49.1198901151546,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XG', 'value': 'IDA total'},
#   'countryiso3code': 'IDA',
#   'date': '2020',
#   'value': 48.8070863185312,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XG', 'value': 'IDA total'},
#   'countryiso3code': 'IDA',
#   'date': '2019',
#   'value': 50.5382194375915,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#   'countryiso3code': 'LTE',
#   'date': '2021',
#   'value': 57.8649015056048,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#   'countryiso3code': 'LTE',
#   'date': '2020',
#   'value': 57.8585577524786,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#   'countryiso3code': 'LTE',
#   'date': '2019',
#   'value': 59.4882482329463,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#   'countryiso3code': 'LCN',
#   'date': '2021',
#   'value': 48.5053462292949,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#   'countryiso3code': 'LCN',
#   'date': '2020',
#   'value': 46.0923869318955,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#   'countryiso3code': 'LCN',
#   'date': '2019',
#   'value': 51.0705999751138,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XJ',
#    'value': 'Latin America & Caribbean (excluding high income)'},
#   'countryiso3code': 'LAC',
#   'date': '2021',
#   'value': 49.3584302903,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XJ',
#    'value': 'Latin America & Caribbean (excluding high income)'},
#   'countryiso3code': 'LAC',
#   'date': '2020',
#   'value': 46.7107325998303,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XJ',
#    'value': 'Latin America & Caribbean (excluding high income)'},
#   'countryiso3code': 'LAC',
#   'date': '2019',
#   'value': 51.8911998009929,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#   'countryiso3code': 'TLA',
#   'date': '2021',
#   'value': 48.7459222863201,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#   'countryiso3code': 'TLA',
#   'date': '2020',
#   'value': 46.2939677219892,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T2', 'value': 'Latin America & Caribbean (IDA & IBRD)'},
#   'countryiso3code': 'TLA',
#   'date': '2019',
#   'value': 51.3393541597499,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XL',
#    'value': 'Least developed countries: UN classification'},
#   'countryiso3code': 'LDC',
#   'date': '2021',
#   'value': 54.696573259058,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XL',
#    'value': 'Least developed countries: UN classification'},
#   'countryiso3code': 'LDC',
#   'date': '2020',
#   'value': 54.324637059507,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XL',
#    'value': 'Least developed countries: UN classification'},
#   'countryiso3code': 'LDC',
#   'date': '2019',
#   'value': 56.432373628826,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XO', 'value': 'Low & middle income'},
#   'countryiso3code': 'LMY',
#   'date': '2021',
#   'value': 44.8428114771401,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XO', 'value': 'Low & middle income'},
#   'countryiso3code': 'LMY',
#   'date': '2020',
#   'value': 44.4236429975584,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XO', 'value': 'Low & middle income'},
#   'countryiso3code': 'LMY',
#   'date': '2019',
#   'value': 46.5046194399056,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XM', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2021',
#   'value': 56.804493186196,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XM', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2020',
#   'value': 56.4437552492749,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XM', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2019',
#   'value': 58.6129258047632,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XN', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2021',
#   'value': 33.5871886698911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XN', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2020',
#   'value': 33.0729978765373,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XN', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2019',
#   'value': 35.0228965465182,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#   'countryiso3code': 'MEA',
#   'date': '2021',
#   'value': 18.6061975464682,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#   'countryiso3code': 'MEA',
#   'date': '2020',
#   'value': 18.4899322414378,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#   'countryiso3code': 'MEA',
#   'date': '2019',
#   'value': 19.4184516540925,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XQ',
#    'value': 'Middle East & North Africa (excluding high income)'},
#   'countryiso3code': 'MNA',
#   'date': '2021',
#   'value': 15.5750315587062,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XQ',
#    'value': 'Middle East & North Africa (excluding high income)'},
#   'countryiso3code': 'MNA',
#   'date': '2020',
#   'value': 15.40314732385,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XQ',
#    'value': 'Middle East & North Africa (excluding high income)'},
#   'countryiso3code': 'MNA',
#   'date': '2019',
#   'value': 16.7020940872534,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#   'countryiso3code': 'TMN',
#   'date': '2021',
#   'value': 15.5630376569383,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#   'countryiso3code': 'TMN',
#   'date': '2020',
#   'value': 15.3949561021216,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T3', 'value': 'Middle East & North Africa (IDA & IBRD)'},
#   'countryiso3code': 'TMN',
#   'date': '2019',
#   'value': 16.6873445920004,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XP', 'value': 'Middle income'},
#   'countryiso3code': 'MIC',
#   'date': '2021',
#   'value': 43.7395051113457,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XP', 'value': 'Middle income'},
#   'countryiso3code': 'MIC',
#   'date': '2020',
#   'value': 43.3355168533402,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XP', 'value': 'Middle income'},
#   'countryiso3code': 'MIC',
#   'date': '2019',
#   'value': 45.4291426160624,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XU', 'value': 'North America'},
#   'countryiso3code': 'NAC',
#   'date': '2021',
#   'value': 55.815312067561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XU', 'value': 'North America'},
#   'countryiso3code': 'NAC',
#   'date': '2020',
#   'value': 55.8249254962835,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XU', 'value': 'North America'},
#   'countryiso3code': 'NAC',
#   'date': '2019',
#   'value': 57.1069801005648,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'OE', 'value': 'OECD members'},
#   'countryiso3code': 'OED',
#   'date': '2021',
#   'value': 51.7968341361096,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'OE', 'value': 'OECD members'},
#   'countryiso3code': 'OED',
#   'date': '2020',
#   'value': 51.2047283394638,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'OE', 'value': 'OECD members'},
#   'countryiso3code': 'OED',
#   'date': '2019',
#   'value': 52.5793238362361,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S4', 'value': 'Other small states'},
#   'countryiso3code': 'OSS',
#   'date': '2021',
#   'value': 50.4454919795437,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S4', 'value': 'Other small states'},
#   'countryiso3code': 'OSS',
#   'date': '2020',
#   'value': 50.2656611867821,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S4', 'value': 'Other small states'},
#   'countryiso3code': 'OSS',
#   'date': '2019',
#   'value': 51.605690373572,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S2', 'value': 'Pacific island small states'},
#   'countryiso3code': 'PSS',
#   'date': '2021',
#   'value': 53.2623404996813,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S2', 'value': 'Pacific island small states'},
#   'countryiso3code': 'PSS',
#   'date': '2020',
#   'value': 53.1868677291755,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S2', 'value': 'Pacific island small states'},
#   'countryiso3code': 'PSS',
#   'date': '2019',
#   'value': 53.6367828105726,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#   'countryiso3code': 'PST',
#   'date': '2021',
#   'value': 53.8655683477543,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#   'countryiso3code': 'PST',
#   'date': '2020',
#   'value': 53.6432714169708,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#   'countryiso3code': 'PST',
#   'date': '2019',
#   'value': 54.3905008082019,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#   'countryiso3code': 'PRE',
#   'date': '2021',
#   'value': 55.1451531143271,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#   'countryiso3code': 'PRE',
#   'date': '2020',
#   'value': 54.8863834785987,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#   'countryiso3code': 'PRE',
#   'date': '2019',
#   'value': 56.4204401996629,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S1', 'value': 'Small states'},
#   'countryiso3code': 'SST',
#   'date': '2021',
#   'value': 50.8560063004472,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S1', 'value': 'Small states'},
#   'countryiso3code': 'SST',
#   'date': '2020',
#   'value': 50.5366837000198,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'S1', 'value': 'Small states'},
#   'countryiso3code': 'SST',
#   'date': '2019',
#   'value': 52.2319067506659,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '8S', 'value': 'South Asia'},
#   'countryiso3code': 'SAS',
#   'date': '2021',
#   'value': 21.9904971349328,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '8S', 'value': 'South Asia'},
#   'countryiso3code': 'SAS',
#   'date': '2020',
#   'value': 21.4377477522558,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': '8S', 'value': 'South Asia'},
#   'countryiso3code': 'SAS',
#   'date': '2019',
#   'value': 23.8605625388155,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#   'countryiso3code': 'TSA',
#   'date': '2021',
#   'value': 21.9904971349328,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#   'countryiso3code': 'TSA',
#   'date': '2020',
#   'value': 21.4377477522558,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#   'countryiso3code': 'TSA',
#   'date': '2019',
#   'value': 23.8605625388155,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': 'SSF',
#   'date': '2021',
#   'value': 60.2199085708754,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': 'SSF',
#   'date': '2020',
#   'value': 59.663110138779,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': 'SSF',
#   'date': '2019',
#   'value': 61.5047379689282,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZF',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'countryiso3code': 'SSA',
#   'date': '2021',
#   'value': 60.2199085708754,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZF',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'countryiso3code': 'SSA',
#   'date': '2020',
#   'value': 59.663110138779,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'ZF',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'countryiso3code': 'SSA',
#   'date': '2019',
#   'value': 61.5047379689282,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T6', 'value': 'Sub-Saharan Africa (IDA & IBRD)'},
#   'countryiso3code': 'TSS',
#   'date': '2021',
#   'value': 60.2199085708754,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T6', 'value': 'Sub-Saharan Africa (IDA & IBRD)'},
#   'countryiso3code': 'TSS',
#   'date': '2020',
#   'value': 59.663110138779,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'T6', 'value': 'Sub-Saharan Africa (IDA & IBRD)'},
#   'countryiso3code': 'TSS',
#   'date': '2019',
#   'value': 61.5047379689282,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)'},
#   'country': {'id': 'XT', 'value': 'Upper middle income'},
#   'countryiso3code': '',
#   'date': '2021',
#   'value': 55.47990165274,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
# ...
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AD', 'value': 'Andorra'},
#   'countryiso3code': 'AND',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AD', 'value': 'Andorra'},
#   'countryiso3code': 'AND',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AO', 'value': 'Angola'},
#   'countryiso3code': 'AGO',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AO', 'value': 'Angola'},
#   'countryiso3code': 'AGO',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AO', 'value': 'Angola'},
#   'countryiso3code': 'AGO',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': 'ATG',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': 'ATG',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': 'ATG',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2020',
#   'value': 46.810001373291,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2019',
#   'value': 50.2999992370605,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AM', 'value': 'Armenia'},
#   'countryiso3code': 'ARM',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AM', 'value': 'Armenia'},
#   'countryiso3code': 'ARM',
#   'date': '2020',
#   'value': 46.2799987792969,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AM', 'value': 'Armenia'},
#   'countryiso3code': 'ARM',
#   'date': '2019',
#   'value': 49.4300003051758,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AW', 'value': 'Aruba'},
#   'countryiso3code': 'ABW',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AW', 'value': 'Aruba'},
#   'countryiso3code': 'ABW',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AW', 'value': 'Aruba'},
#   'countryiso3code': 'ABW',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AU', 'value': 'Australia'},
#   'countryiso3code': 'AUS',
#   'date': '2021',
#   'value': 61.2200012207031,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AU', 'value': 'Australia'},
#   'countryiso3code': 'AUS',
#   'date': '2020',
#   'value': 60.2099990844727,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AU', 'value': 'Australia'},
#   'countryiso3code': 'AUS',
#   'date': '2019',
#   'value': 60.9599990844727,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AT', 'value': 'Austria'},
#   'countryiso3code': 'AUT',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AT', 'value': 'Austria'},
#   'countryiso3code': 'AUT',
#   'date': '2020',
#   'value': 55.6399993896484,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AT', 'value': 'Austria'},
#   'countryiso3code': 'AUT',
#   'date': '2019',
#   'value': 56,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#   'countryiso3code': 'AZE',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#   'countryiso3code': 'AZE',
#   'date': '2020',
#   'value': 64,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#   'countryiso3code': 'AZE',
#   'date': '2019',
#   'value': 63.2999992370605,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BS', 'value': 'Bahamas, The'},
#   'countryiso3code': 'BHS',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BS', 'value': 'Bahamas, The'},
#   'countryiso3code': 'BHS',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BS', 'value': 'Bahamas, The'},
#   'countryiso3code': 'BHS',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BH', 'value': 'Bahrain'},
#   'countryiso3code': 'BHR',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BH', 'value': 'Bahrain'},
#   'countryiso3code': 'BHR',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BH', 'value': 'Bahrain'},
#   'countryiso3code': 'BHR',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BD', 'value': 'Bangladesh'},
#   'countryiso3code': 'BGD',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BD', 'value': 'Bangladesh'},
#   'countryiso3code': 'BGD',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BD', 'value': 'Bangladesh'},
#   'countryiso3code': 'BGD',
#   'date': '2019',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BB', 'value': 'Barbados'},
#   'countryiso3code': 'BRB',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BB', 'value': 'Barbados'},
#   'countryiso3code': 'BRB',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BB', 'value': 'Barbados'},
#   'countryiso3code': 'BRB',
#   'date': '2019',
#   'value': 59.0299987792969,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BY', 'value': 'Belarus'},
#   'countryiso3code': 'BLR',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BY', 'value': 'Belarus'},
#   'countryiso3code': 'BLR',
#   'date': '2020',
#   'value': 65.6800003051758,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BY', 'value': 'Belarus'},
#   'countryiso3code': 'BLR',
#   'date': '2019',
#   'value': 66.3000030517578,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BE', 'value': 'Belgium'},
#   'countryiso3code': 'BEL',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BE', 'value': 'Belgium'},
#   'countryiso3code': 'BEL',
#   'date': '2020',
#   'value': 49.3400001525879,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BE', 'value': 'Belgium'},
#   'countryiso3code': 'BEL',
#   'date': '2019',
#   'value': 49.8300018310547,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BZ', 'value': 'Belize'},
#   'countryiso3code': 'BLZ',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BZ', 'value': 'Belize'},
#   'countryiso3code': 'BLZ',
#   'date': '2020',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BZ', 'value': 'Belize'},
#   'countryiso3code': 'BLZ',
#   'date': '2019',
#   'value': 57.189998626709,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'SL.TLF.CACT.FE.NE.ZS',
#    'value': 'Labor force participation rate, female (% of female population ages 15+) (national estimate)'},
#   'country': {'id': 'BJ', 'value': 'Benin'},
#   'countryiso3code': 'BEN',
#   'date': '2021',
#   'value': None,
#   'scale': '',
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  ...]

# %%
df = pd.DataFrame(data[1])

# %%
df.head()
# Out:
#                                            indicator  \
# 0  {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 1  {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 2  {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 3  {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 4  {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
#
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2019
# 3  {'id': 'ZI', 'value': 'Africa Western and Cent...             AFW  2021
# 4  {'id': 'ZI', 'value': 'Africa Western and Cent...             AFW  2020
#
#        value unit obs_status  decimal scale
# 0  64.878121                        0   NaN
# 1  64.111891                        0   NaN
# 2  66.362142                        0   NaN
# 3  52.990872                        0   NaN
# 4  52.764629                        0   NaN

# %%
df['country']
# Out:
# 0        {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 1        {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 2        {'id': 'ZH', 'value': 'Africa Eastern and Sout...
# 3        {'id': 'ZI', 'value': 'Africa Western and Cent...
# 4        {'id': 'ZI', 'value': 'Africa Western and Cent...
#                                ...
# 11920                      {'id': 'ZM', 'value': 'Zambia'}
# 11921                      {'id': 'ZM', 'value': 'Zambia'}
# 11922                    {'id': 'ZW', 'value': 'Zimbabwe'}
# 11923                    {'id': 'ZW', 'value': 'Zimbabwe'}
# 11924                    {'id': 'ZW', 'value': 'Zimbabwe'}
# Name: country, Length: 11925, dtype: object

# %%
df['country_v2'] = df['country'].apply(lambda x: x['value'])

df
# Out:
#                                                indicator  \
# 0      {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 1      {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 2      {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 3      {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# 4      {'id': 'SL.TLF.CACT.FE.ZS', 'value': 'Labor fo...
# ...                                                  ...
# 11920  {'id': 'SL.TLF.ACTI.ZS', 'value': 'Labor force...
# 11921  {'id': 'SL.TLF.ACTI.ZS', 'value': 'Labor force...
# 11922  {'id': 'SL.TLF.ACTI.ZS', 'value': 'Labor force...
# 11923  {'id': 'SL.TLF.ACTI.ZS', 'value': 'Labor force...
# 11924  {'id': 'SL.TLF.ACTI.ZS', 'value': 'Labor force...
#
#                                                  country countryiso3code  \
# 0      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 1      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 2      {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE
# 3      {'id': 'ZI', 'value': 'Africa Western and Cent...             AFW
# 4      {'id': 'ZI', 'value': 'Africa Western and Cent...             AFW
# ...                                                  ...             ...
# 11920                    {'id': 'ZM', 'value': 'Zambia'}             ZMB
# 11921                    {'id': 'ZM', 'value': 'Zambia'}             ZMB
# 11922                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 11923                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
# 11924                  {'id': 'ZW', 'value': 'Zimbabwe'}             ZWE
#
#        date      value unit obs_status  decimal scale  \
# 0      2021  64.878121                        0   NaN
# 1      2020  64.111891                        0   NaN
# 2      2019  66.362142                        0   NaN
# 3      2021  52.990872                        0   NaN
# 4      2020  52.764629                        0   NaN
# ...     ...        ...  ...        ...      ...   ...
# 11920  2020        NaN                        1
# 11921  2019  75.130000                        1   NaN
# 11922  2021        NaN                        1
# 11923  2020        NaN                        1
# 11924  2019  83.980000                        1   NaN
#
#                         country_v2
# 0      Africa Eastern and Southern
# 1      Africa Eastern and Southern
# 2      Africa Eastern and Southern
# 3       Africa Western and Central
# 4       Africa Western and Central
# ...                            ...
# 11920                       Zambia
# 11921                       Zambia
# 11922                     Zimbabwe
# 11923                     Zimbabwe
# 11924                     Zimbabwe
#
# [11925 rows x 10 columns]

# %%
df[['date', 'country_v2', 'value']].round(2).dropna().to_csv('labour_force.csv', sep=',', encoding='utf-8')
