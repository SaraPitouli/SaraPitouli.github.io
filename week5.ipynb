# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraPitouli/SaraPitouli.github.io/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import json

# %%
from google.colab import files

# %%
url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/qna/data"
ons_series = ['ABMI','YBEZ','IHYP','IHYC','IHYS','IHXW','IHYD','BKTL','MNF2']

for i in ons_series:
  URL = url_base.format(i)
  print(URL)
# Out:
# https://api.ons.gov.uk/timeseries/ABMI/dataset/qna/data
# https://api.ons.gov.uk/timeseries/YBEZ/dataset/qna/data
# https://api.ons.gov.uk/timeseries/IHYP/dataset/qna/data
# https://api.ons.gov.uk/timeseries/IHYC/dataset/qna/data
# https://api.ons.gov.uk/timeseries/IHYS/dataset/qna/data
# https://api.ons.gov.uk/timeseries/IHXW/dataset/qna/data
# https://api.ons.gov.uk/timeseries/IHYD/dataset/qna/data
# https://api.ons.gov.uk/timeseries/BKTL/dataset/qna/data
# https://api.ons.gov.uk/timeseries/MNF2/dataset/qna/data

# %%
url = "https://api.ons.gov.uk/timeseries/ABMI/dataset/qna/data"
data = requests.get(url).json()
data
# Out:
# {'description': {'cdid': 'ABMI',
#   'contact': {'email': 'gdp@ons.gov.uk',
#    'name': 'Rachel Meyrick',
#    'telephone': '+44 1633 455284'},
#   'datasetId': 'QNA',
#   'datasetUri': '/economy/grossdomesticproductgdp/datasets/quarterlynationalaccounts',
#   'date': '2022 Q2',
#   'keyNote': 'Chained Volume Measures (CVM)',
#   'nextRelease': '11 November 2022',
#   'number': '560089',
#   'preUnit': '£',
#   'releaseDate': '2022-09-29T23:00:00.000Z',
#   'sampleSize': '0',
#   'source': '',
#   'title': 'Gross Domestic Product: chained volume measures: Seasonally adjusted £m',
#   'unit': 'm'},
#  'months': [],
#  'quarters': [{'date': '1955 Q1',
#    'label': '1955 Q1',
#    'month': '',
#    'quarter': 'Q1',
#    'sourceDataset': 'QNA',
#    'updateDate': '2022-09-29T23:00:00.000Z',
#    'value': '129428',
#    'year': '1955'},
#   {'date': '1955 Q2',
#    'label': '1955 Q2',
#    'month': '',
#    'quarter': 'Q2',
#    'sourceDataset': 'QNA',
# ...

# %%
#create a loop to save file names
file_base = "data_ONS-{}.json"
for i in ons_series:
   print("------Iteration Starts--------")
   print(i) 
   # // Build the URL for this iteration of the loop, and check what we are getting:
   URL = url_base.format(i)
   print(URL)
     
   # // Request the html from the URL:
   data = requests.get(URL).json()
   print(data)

   # // Set the filename, and check what we are getting:
   fileName = file_base.format(i)
   print(fileName)
   
   # // Add some white space to our output. (This is purely so we can see what is happening below clearly)
   print("------Iteration Ends--------")

   # /// Save the file:
   with open(fileName, 'w', encoding='utf-8') as f:
     json.dump(data, f, ensure_ascii=False, indent=4)

   # /// Download the file to local machine:
   files.download(fileName)
# Out:
# ------Iteration Starts--------
# ABMI
# https://api.ons.gov.uk/timeseries/ABMI/dataset/qna/data
# ...
